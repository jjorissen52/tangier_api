# %%
thing = """
 ******   **     ** **       **       **      **   *******   *******   ****     **
/*////** /**    /**/**      /**      /**     /**  **/////** /**////** /**/**   /**
/*   /** /**    /**/**      /**      /**     /** **     //**/**   /** /**//**  /**
/******  /**    /**/**      /**      /**********/**      /**/*******  /** //** /**
/*//// **/**    /**/**      /**      /**//////**/**      /**/**///**  /**  //**/**
/*    /**/**    /**/**      /**      /**     /**//**     ** /**  //** /**   //****
/******* //******* /********/********/**     /** //*******  /**   //**/**    //***
///////   ///////  //////// //////// //      //   ///////   //     // //      /// 
"""
new_thing = ">```colossal\n"
for line in thing.split('\n'):
    new_thing += f'>{line}\n'
new_thing += ">```"
print(new_thing)
# Out:
# >```colossal
# >
# > ******   **     ** **       **       **      **   *******   *******   ****     **
# >/*////** /**    /**/**      /**      /**     /**  **/////** /**////** /**/**   /**
# >/*   /** /**    /**/**      /**      /**     /** **     //**/**   /** /**//**  /**
# >/******  /**    /**/**      /**      /**********/**      /**/*******  /** //** /**
# >/*//// **/**    /**/**      /**      /**//////**/**      /**/**///**  /**  //**/**
# >/*    /**/**    /**/**      /**      /**     /**//**     ** /**  //** /**   //****
# >/******* //******* /********/********/**     /** //*******  /**   //**/**    //***
# >///////   ///////  //////// //////// //      //   ///////   //     // //      ///
# >
# >```

# %%
thing = """
 ########:: ##:::: ##: ##::::::: ##::::::: ##:::: ##:: #######:: ########:: ##::: ##:
 ##.... ##: ##:::: ##: ##::::::: ##::::::: ##:::: ##:'##.... ##: ##.... ##: ###:: ##:
 ##:::: ##: ##:::: ##: ##::::::: ##::::::: ##:::: ##: ##:::: ##: ##:::: ##: ####: ##:
 ########:: ##:::: ##: ##::::::: ##::::::: #########: ##:::: ##: ########:: ## ## ##:
 ##.... ##: ##:::: ##: ##::::::: ##::::::: ##.... ##: ##:::: ##: ##.. ##::: ##. ####:
 ##:::: ##: ##:::: ##: ##::::::: ##::::::: ##:::: ##: ##:::: ##: ##::. ##:: ##:. ###:
 ########::. #######:: ########: ########: ##:::: ##:. #######:: ##:::. ##: ##::. ##:
........::::.......:::........::........::..:::::..:::.......:::..:::::..::..::::..::
:::::::::'####:'##::: ##:'########:'########:'########::'########::::'###:::::'######::'########:
:::::::::. ##:: ###:: ##:... ##..:: ##.....:: ##.... ##: ##.....::::'## ##:::'##... ##: ##.....::
:::::::::: ##:: ####: ##:::: ##:::: ##::::::: ##:::: ##: ##::::::::'##:. ##:: ##:::..:: ##:::::::
:::::::::: ##:: ## ## ##:::: ##:::: ######::: ########:: ######:::'##:::. ##: ##::::::: ######:::
:::::::::: ##:: ##. ####:::: ##:::: ##...:::: ##.. ##::: ##...:::: #########: ##::::::: ##...::::
:::::::::: ##:: ##:. ###:::: ##:::: ##::::::: ##::. ##:: ##::::::: ##.... ##: ##::: ##: ##:::::::
::::::::::####: ##::. ##:::: ##:::: ########: ##:::. ##: ##::::::: ##:::: ##:. ######:: ########:
.......::....::..::::..:::::..:::::........::..:::::..::..::::::::..:::::..:::......:::........::
"""
new_thing = ">```banner3d\n"
for line in thing.split('\n'):
    new_thing += f'>{line}\n'
new_thing += ">```"
print(new_thing)
# Out:
# >```banner3d
# >
# > ########:: ##:::: ##: ##::::::: ##::::::: ##:::: ##:: #######:: ########:: ##::: ##:
# > ##.... ##: ##:::: ##: ##::::::: ##::::::: ##:::: ##:'##.... ##: ##.... ##: ###:: ##:
# > ##:::: ##: ##:::: ##: ##::::::: ##::::::: ##:::: ##: ##:::: ##: ##:::: ##: ####: ##:
# > ########:: ##:::: ##: ##::::::: ##::::::: #########: ##:::: ##: ########:: ## ## ##:
# > ##.... ##: ##:::: ##: ##::::::: ##::::::: ##.... ##: ##:::: ##: ##.. ##::: ##. ####:
# > ##:::: ##: ##:::: ##: ##::::::: ##::::::: ##:::: ##: ##:::: ##: ##::. ##:: ##:. ###:
# > ########::. #######:: ########: ########: ##:::: ##:. #######:: ##:::. ##: ##::. ##:
# >........::::.......:::........::........::..:::::..:::.......:::..:::::..::..::::..::
# >:::::::::'####:'##::: ##:'########:'########:'########::'########::::'###:::::'######::'########:
# >:::::::::. ##:: ###:: ##:... ##..:: ##.....:: ##.... ##: ##.....::::'## ##:::'##... ##: ##.....::
# ...
